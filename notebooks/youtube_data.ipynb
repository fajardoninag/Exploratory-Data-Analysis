# %%
# Source code for loading the dataset
import pandas as pd
from google.colab import files
uploaded = files.upload()

dataSet = "Most Subscribed YouTube Channels.csv"

df = pd.read_csv(dataSet)
df.head()
# Out:
#      <input type="file" id="files-2c21f339-6e8d-45d9-a413-44a75cfd9409" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c21f339-6e8d-45d9-a413-44a75cfd9409">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Source code for creating a dataframe from dictionary of list

pd.DataFrame()
raw_data = {
    'Name': ['T-Series', 'MrBeast', 'PewDiePie', 'HYBE LABELS', '5-Minute Crafts'],
    'Brand channel': ['Yes', 'No', 'No', 'Yes', 'Yes'],
    'Subscribers (millions)': [249.0, 184.0, 111.0, 76.7, 80.0],
    'Primary language': ['Hindi', 'English', 'English', 'Korean', 'English'],
    'Country': ['India', 'United States', 'Sweden', 'South Korea', 'Russia'],
    'Category': ['Music', 'Entertainment', 'Entertainment', 'Music', 'Education']
}

# Create the DataFrame
raw_df = pd.DataFrame(raw_data)
raw_df.head()
# Out:
#               Name Brand channel  Subscribers (millions) Primary language  \
# 0         T-Series           Yes                   249.0            Hindi
# 1          MrBeast            No                   184.0          English
# 2        PewDiePie            No                   111.0          English
# 3      HYBE LABELS           Yes                    76.7           Korean
# 4  5-Minute Crafts           Yes                    80.0          English
#
#          Country       Category
# 0          India          Music
# 1  United States  Entertainment
# 2         Sweden  Entertainment
# 3    South Korea          Music
# 4         Russia      Education

# %%
# Source code for creating list of dictionaries
data_raw = [
    {'Name': 'T-Series', 'Brand channel': 'Yes', 'Subscribers (millions)': 249.0,
     'Primary language': 'Hindi', 'Category': 'Music', 'Country': 'India'},
    {'Name': 'MrBeast', 'Brand channel': 'No', 'Subscribers (millions)': 184.0,
     'Primary language': 'English', 'Category': 'Entertainment', 'Country': 'United States'},
    {'Name': 'PewDiePie', 'Brand channel': 'No', 'Subscribers (millions)': 111.0,
     'Primary language': 'English', 'Category': 'Entertainment', 'Country': 'Sweden'},
    {'Name': 'HYBE LABELS', 'Brand channel': 'Yes', 'Subscribers (millions)': 75.0,
     'Primary language': 'Korean', 'Category': 'Music', 'Country': 'South Korea'},
    {'Name': '5-Minute Crafts', 'Brand channel': 'Yes', 'Subscribers (millions)': 78.0,
     'Primary language': 'English', 'Category': 'How-to', 'Country': 'Cyprus'}
]

# Creating the DataFrame
data_df = pd.DataFrame(data_raw)
data_df.head()
# Out:
#               Name Brand channel  Subscribers (millions) Primary language  \
# 0         T-Series           Yes                   249.0            Hindi
# 1          MrBeast            No                   184.0          English
# 2        PewDiePie            No                   111.0          English
# 3      HYBE LABELS           Yes                    75.0           Korean
# 4  5-Minute Crafts           Yes                    78.0          English
#
#         Category        Country
# 0          Music          India
# 1  Entertainment  United States
# 2  Entertainment         Sweden
# 3          Music    South Korea
# 4         How-to         Cyprus

# %%
#Source code for selecting single column
data_df['Name']
# Out:
# 0           T-Series
# 1            MrBeast
# 2          PewDiePie
# 3        HYBE LABELS
# 4    5-Minute Crafts
# Name: Name, dtype: object

# %%
#Source code fo relecting multiple columns
data_df[['Name','Subscribers (millions)','Category']]
# Out:
#               Name  Subscribers (millions)       Category
# 0         T-Series                   249.0          Music
# 1          MrBeast                   184.0  Entertainment
# 2        PewDiePie                   111.0  Entertainment
# 3      HYBE LABELS                    75.0          Music
# 4  5-Minute Crafts                    78.0         How-to

# %%
#Source code for selecting single row using python indexing
df.loc[5]
# Out:
# Name                          PewDiePie
# Brand channel                        No
# Subscribers (millions)            111.0
# Primary language                English
# Category                  Entertainment
# Country                          Sweden
# Name: 5, dtype: object

# %%
#Source code for selecting single row using python indexing
df.iloc[5]
# Out:
# Name                          PewDiePie
# Brand channel                        No
# Subscribers (millions)            111.0
# Primary language                English
# Category                  Entertainment
# Country                          Sweden
# Name: 5, dtype: object

# %%
#Source code for selecting multiple rows using panda
data_df.loc[0:3]
# Out:
#           Name Brand channel  Subscribers (millions) Primary language  \
# 0     T-Series           Yes                   249.0            Hindi
# 1      MrBeast            No                   184.0          English
# 2    PewDiePie            No                   111.0          English
# 3  HYBE LABELS           Yes                    75.0           Korean
#
#         Category        Country
# 0          Music          India
# 1  Entertainment  United States
# 2  Entertainment         Sweden
# 3          Music    South Korea

# %%
#Source code for selecting multiple rows using panda
data_df.iloc[0:3]
# Out:
#         Name Brand channel  Subscribers (millions) Primary language  \
# 0   T-Series           Yes                   249.0            Hindi
# 1    MrBeast            No                   184.0          English
# 2  PewDiePie            No                   111.0          English
#
#         Category        Country
# 0          Music          India
# 1  Entertainment  United States
# 2  Entertainment         Sweden

# %%
#Source code of getting specific columns
df.get(['Name','Category','Country'])
# Out:
#                                      Name       Category  \
# 0                                T-Series          Music
# 1                                 MrBeast  Entertainment
# 2                               Cocomelon      Education
# 3     Sony Entertainment Television India  Entertainment
# 4                         Kids Diana Show  Entertainment
# 5                               PewDiePie  Entertainment
# 6                             Like Nastya  Entertainment
# 7                           Vlad and Niki  Entertainment
# 8                       Zee Music Company          Music
# 9                                     WWE         Sports
# 10                              Blackpink          Music
# 11                              Goldmines           Film
# 12                               Sony SAB  Entertainment
# 13                        5-Minute Crafts         How-to
# 14                              BangtanTV          Music
# ...

# %%
df.pop('Primary language')
# Out:
# 0             Hindi[7][8]
# 1                 English
# 2                 English
# 3                Hindi[9]
# 4     English[10][11][12]
# 5                 English
# 6                 English
# 7                 English
# 8           Hindi[13][14]
# 9                 English
# 10                 Korean
# 11                  Hindi
# 12                  Hindi
# 13                English
# 14                 Korean
# 15                 Korean
# 16                  Hindi
# 17                English
# 18                English
# 19              Hindi[16]
# 20             Portuguese
# 21                  Hindi
# 22                  Hindi
# 23                  Hindi
# 24                  Hindi
# 25                English
# 26                English
# 27                Spanish
# 28                  Hindi
# 29               Bhojpuri
# 30                  Hindi
# 31                English
# 32                English
# 33                  Hindi
# 34                  Hindi
# ...

# %%
df.drop(index=[0,1,2,3,4,5])
# Out:
#                                      Name Brand channel  \
# 6                             Like Nastya            No
# 7                           Vlad and Niki            No
# 8                       Zee Music Company           Yes
# 9                                     WWE           Yes
# 10                              Blackpink            No
# 11                              Goldmines           Yes
# 12                               Sony SAB           Yes
# 13                        5-Minute Crafts           Yes
# 14                              BangtanTV            No
# 15                            Hybe Labels           Yes
# 16                                 Zee TV           Yes
# 17                          Justin Bieber            No
# 18                               Pinkfong           Yes
# 19  ChuChu TV Nursery Rhymes & Kids Songs           Yes
# 20                        Canal KondZilla           Yes
# 21                              Colors TV           Yes
# ...

# %%
df.sort_values('Subscribers (millions)', ascending=False)
# Out:
#                                      Name Brand channel  \
# 0                                T-Series           Yes
# 1                                 MrBeast            No
# 2                               Cocomelon           Yes
# 3     Sony Entertainment Television India           Yes
# 4                         Kids Diana Show           Yes
# 5                               PewDiePie            No
# 6                             Like Nastya            No
# 7                           Vlad and Niki            No
# 8                       Zee Music Company           Yes
# 9                                     WWE           Yes
# 10                              Blackpink            No
# 11                              Goldmines           Yes
# 12                               Sony SAB           Yes
# 13                        5-Minute Crafts           Yes
# 14                              BangtanTV            No
# 15                            Hybe Labels           Yes
# ...

# %%
top_10 = df.nlargest(10, 'Subscribers (millions)')
print(top_10[['Name', 'Subscribers (millions)']])
# Out:
#                                   Name  Subscribers (millions)
# 0                             T-Series                   249.0
# 1                              MrBeast                   184.0
# 2                            Cocomelon                   165.0
# 3  Sony Entertainment Television India                   162.0
# 4                      Kids Diana Show                   113.0
# 5                            PewDiePie                   111.0
# 6                          Like Nastya                   107.0
# 7                        Vlad and Niki                   101.0
# 8                    Zee Music Company                    99.5
# 9                                  WWE                    97.1

# %%
top_5 = df.nlargest(5, 'Subscribers (millions)')
top_5.plot(x='Name', y='Subscribers (millions)', kind='bar', title='Top 5 YouTube Channels')
# Out:
# <Axes: title={'center': 'Top 5 YouTube Channels'}, xlabel='Name'>
